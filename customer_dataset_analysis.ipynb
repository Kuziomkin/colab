# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuziomkin/colab/blob/main/customer_dataset_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Settings

# %%
import duckdb

# %%
# %pip install jupysql duckdb-engine --quiet

# %%
# %load_ext sql
conn = duckdb.connect()
# %sql conn --alias duckdb

# %% [markdown]
# # Dataset Analysis

# %%
# %%sql
#
# SELECT *
# FROM
#   '/content/laptop_purchase_data_india.csv'
# Out:
# Running query in 'duckdb'
# +-------------+-----+--------+-----------+--------------+---------------+-----------------+-------------+--------------+--------------------+---------------------+
# | Customer_ID | Age | Gender |    City   | Income_Level | Purchase_Mode | Brand_Purchased | Price_Range | Payment_Mode | Purchase_Frequency | Satisfaction_Rating |
# +-------------+-----+--------+-----------+--------------+---------------+-----------------+-------------+--------------+--------------------+---------------------+
# |  CUST00001  |  56 |  Male  |    Pune   |     Low      |     Online    |       Dell      |   30K-50K   |     UPI      |        Rare        |          4          |
# |  CUST00002  |  46 | Female |  Kolkata  |    Medium    |     Online    |       MSI       |  Below 30K  |     Cash     |     Occasional     |          2          |
# ...

# %%
# %%sql
#
# SUMMARIZE TABLE '/content/laptop_purchase_data_india.csv'
# Out:
# Running query in 'duckdb'
# +--------------------+-------------+-----------+-----------+---------------+---------+-------------------+------+------+------+-------+-----------------+
# |    column_name     | column_type |    min    |    max    | approx_unique |   avg   |        std        | q25  | q50  | q75  | count | null_percentage |
# +--------------------+-------------+-----------+-----------+---------------+---------+-------------------+------+------+------+-------+-----------------+
# |    Customer_ID     |   VARCHAR   | CUST00001 | CUST05000 |      3925     |   None  |        None       | None | None | None |  5000 |       0.00      |
# |        Age         |    BIGINT   |     18    |     59    |       37      | 38.6622 | 12.02849234466304 |  28  |  39  |  49  |  5000 |       0.00      |
# |       Gender       |   VARCHAR   |   Female  |    Male   |       2       |   None  |        None       | None | None | None |  5000 |       0.00      |
# ...

# %%
# %sqlcmd profile --table '/content/laptop_purchase_data_india.csv'
# Out:
# +--------+-------------+---------+--------+---------+--------------+---------------+-----------------+-------------+--------------+--------------------+---------------------+
# |        | Customer_ID |   Age   | Gender |   City  | Income_Level | Purchase_Mode | Brand_Purchased | Price_Range | Payment_Mode | Purchase_Frequency | Satisfaction_Rating |
# +--------+-------------+---------+--------+---------+--------------+---------------+-----------------+-------------+--------------+--------------------+---------------------+
# | count  |     5000    |   5000  |  5000  |   5000  |     5000     |      5000     |       5000      |     5000    |     5000     |        5000        |         5000        |
# | unique |     5000    |    42   |   2    |    9    |      3       |       2       |        8        |      5      |      5       |         3          |          5          |
# ...
